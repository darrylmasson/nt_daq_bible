# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# !mkdir digitizers

# %%
# figure about timestamp rollovers

plt.figure(figsize=(13,7))

plt.vlines(np.arange(3)*21.5, 0, 1, colors=['r']*4)
plt.vlines([10, 31,32], 0.2, 0.8, colors=['g','b','cyan'], ls='--')
plt.text(10,0.82, 'Realtime: 10s\nDigitime: 10s', color='g', fontsize=14, ha='center')
plt.text(31, 0.82, 'Realtime: 31s\nDigitime: %.1fs' % (31%21.5), color='b', fontsize=14, ha='center')
plt.text(32, 0.1, 'Realtime: 32s\nDigitime: %.1fs' % (32%21.5), color='cyan', fontsize=14, ha='center')

plt.xlabel('Time', fontsize=18)
plt.xticks(np.arange(3)*21.5, fontsize=16)
plt.yticks([])

plt.savefig('digitizers/missed_rollover.pdf', bbox_inches='tight')
plt.show()
